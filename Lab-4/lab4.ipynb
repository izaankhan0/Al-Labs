# %% [markdown]
# #BFS

# %% [markdown]
# #eg1 bfs

# %% [markdown]
# ![CamScanner 01-29-2025 22.03_1.jpg](data:image/jpeg;base64,...)

# %%
l= [1,2,34,65]
l.append(77)
l.pop(0)
# Out:
# 1

# %%
l=[99,88]
l.append()

# %%
# tree Representation
tree = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F', 'G'],
    'D': ['H'],
    'E': [],
    'F': ['I'],
    'G': [],
    'H': [],
    'I': []
}

# BFS Function
def bfs(graph, start, goal):
    visited = []  # List for visited nodes   []  ... [A]
    queue = []    # Initialize a queue      [] .... [A]
    visited.append(start)
    queue.append(start)

    while queue:
        node = queue.pop(0)  # Dequeue
        print(node, end=" ")
        if node == goal:  # Stop if goal is found
            print("\nGoal found!")
            break

        for neighbour in graph[node]:    # node='A'
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)

# Define Start and Goal Nodes
start_node = 'A'
goal_node = 'H'

# Run BFS
print("\nFollowing is the Breadth-First Search (BFS):")
bfs(tree, start_node, goal_node)
# Out:
# Following is the Breadth-First Search (BFS):
# A B C D E F G H
# Goal found!

# %%
tree = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F', 'G'],
    'D': ['H'],
    'E': [],
    'F': ['I'],
    'G': [],
    'H': [],
    'I': []
}
class goalbase:
    def __init__(self,goal):
        self.goal=goal

    def formulate_goal(self,percept):
        if percept == self.goal:
            return 'goal reached '
        else:
            return 'searching'
        
    def bfs(self,graph, start, goal):
        visited = []
        queue = []

        visited.append(start)
        queue.append(start)

        while queue:
            node = queue.pop(0)   # FIFO
            print("Visited:", node)

            if node == goal:
                print("Goal found!")
                return

            for child in graph[node]:
                if child not in visited:
                    visited.append(child)
                    queue.append(child)
    
    def act(self,percept,graph):
        action = self.formulate_goal(percept)
        if action =='goal reached':
            return f'{self.goal} is found'
        else:
            self.bfs(graph, percept, self.goal)


class Environment:
    def __init__(self, graph):
        #Initial graph/tree/maze
        self.graph = graph

    def get_percept(self, node):
        return node


def run_agent(agent, environment, start_node):
    percept = environment.get_percept(start_node)
    action = agent.act(percept, environment.graph)  # Pass graph to agent
    print(action)

              
start_node = 'A'
goal_node = 'H'

g=goalbase(goal_node)
e=Environment(tree)
run_agent(g,e,start_node)
# Out:
# Visited: A
# Visited: B
# Visited: C
# Visited: D
# Visited: E
# Visited: F
# Visited: G
# Visited: H
# Goal found!
# None

# %%
#Same example to check Visited and Frontier(Queue)
tree = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F', 'G'],
    'D': ['H'],
    'E': [],
    'F': ['I'],
    'G': [],
    'H': [],
    'I': []
}

# BFS Function with Visited and Queue Tracking
def bfs(graph, start, goal):
    visited = []  # List for visited nodes
    queue = []    # Initialize a queue

    visited.append(start)
    queue.append(start)

    print(f"Initial Queue: {queue}")

    while queue:
        node = queue.pop(0)  # Dequeue
        print(f"Visited: {visited}")
        print(f"Dequeued: {node}")
        print(f"Queue: {queue}")

        if node == goal:  # Stop if goal is found
            print("\nGoal found!")
            break

        for neighbour in graph[node]:
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)

        print(f"Updated Queue: {queue}\n")

# Define Start and Goal Nodes
start_node = 'A'
goal_node = 'I'

# Run BFS
print("\nFollowing is the Breadth-First Search (BFS):")
bfs(tree, start_node, goal_node)
# Out:
# Following is the Breadth-First Search (BFS):
# Initial Queue: ['A']
# Visited: ['A']
# Dequeued: A
# Queue: []
# Updated Queue: ['B', 'C']
#
# Visited: ['A', 'B', 'C']
# Dequeued: B
# Queue: ['C']
# Updated Queue: ['C', 'D', 'E']
#
# Visited: ['A', 'B', 'C', 'D', 'E']
# Dequeued: C
# Queue: ['D', 'E']
# Updated Queue: ['D', 'E', 'F', 'G']
#
# Visited: ['A', 'B', 'C', 'D', 'E', 'F', 'G']
# Dequeued: D
# Queue: ['E', 'F', 'G']
# Updated Queue: ['E', 'F', 'G', 'H']
#
# Visited: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
# Dequeued: E
# Queue: ['F', 'G', 'H']
# Updated Queue: ['F', 'G', 'H']
#
# Visited: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
# Dequeued: F
# Queue: ['G', 'H']
# Updated Queue: ['G', 'H', 'I']
#
# Visited: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
# Dequeued: G
# Queue: ['H', 'I']
# Updated Queue: ['H', 'I']
#
# Visited: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
# Dequeued: H
# Queue: ['I']
# Updated Queue: ['I']
#
# Visited: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
# Dequeued: I
# Queue: []
#
# Goal found!

# %% [markdown]
# #Converting Eg#1 in Goal Based Agent

# %%
class GoalBasedAgent:
    def __init__(self, goal):
        self.goal = goal

    def formulate_goal(self, percept):
        if percept == self.goal:
            return "Goal reached"
        return "Searching"

    def bfs_search(self, graph, start, goal):
        visited = []  # List for visited nodes
        queue = []    # Initialize a queue

        visited.append(start)
        queue.append(start)

        while queue:
            node = queue.pop(0)  # Dequeue
            print(f"Visiting: {node}")

            if node == goal:  # Stop if goal is found
                return f"Goal {goal} found!"

            for neighbour in graph.get(node, []):
                if neighbour not in visited:
                    visited.append(neighbour)
                    queue.append(neighbour)

        return "Goal not found"

    def act(self, percept, graph):
        goal_status = self.formulate_goal(percept)
        if goal_status == "Goal reached":
            return f"Goal {self.goal} found!"
        else:
            return self.bfs_search(graph, percept, self.goal)


class Environment:
    def __init__(self, graph):
        #Initial graph/tree/maze
        self.graph = graph

    def get_percept(self, node):
        return node


def run_agent(agent, environment, start_node):
    percept = environment.get_percept(start_node)
    action = agent.act(percept, environment.graph)  # Pass graph to agent
    print(action)


# Tree Representation
tree = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F', 'G'],
    'D': ['H'],
    'E': [],
    'F': ['I'],
    'G': [],
    'H': [],
    'I': []
}

# Define Start and Goal Nodes
start_node = 'A'
goal_node = 'I'

# Create instances of agent and environment
agent = GoalBasedAgent(goal_node)
environment = Environment(tree)

# Run the agent
run_agent(agent, environment, start_node)
# Out:
# Visiting: A
# Visiting: B
# Visiting: C
# Visiting: D
# Visiting: E
# Visiting: F
# Visiting: G
# Visiting: H
# Visiting: I
# Goal I found!

# %%
#if we want to make changes in environment (agent action affected the environment)
# class GoalBasedAgent:
#     def __init__(self, goal):
#         self.goal = goal

#     def formulate_goal(self, percept):
#         if percept == self.goal:
#             return "Goal reached"
#         return "Searching"

#     def bfs_search(self, environment, start, goal):
#         visited = []  # List for visited nodes
#         queue = []    # Initialize a queue

#         visited.append(start)
#         queue.append(start)

#         while queue:
#             node = queue.pop(0)  # Dequeue
#             print(f"Visiting: {node}")

#             # Update environment to show the search progress
#             environment.mark_visited(node)

#             if node == goal:  # Stop if goal is found
#                 environment.mark_goal_found(node)
#                 return f"Goal {goal} found!"

#             for neighbour in environment.graph.get(node, []):
#                 if neighbour not in visited:
#                     visited.append(neighbour)
#                     queue.append(neighbour)

#         return "Goal not found"

#     def act(self, percept, environment):
#         goal_status = self.formulate_goal(percept)
#         if goal_status == "Goal reached":
#             environment.mark_goal_found(percept)
#             return f"Goal {self.goal} found!"
#         else:
#             return self.bfs_search(environment, percept, self.goal)


# class Environment:
#     def __init__(self, graph):
#         # Initial graph/tree/maze
#         self.graph = graph
#         self.visited_nodes = list()  # Track visited nodes
#         self.goal_found = False  # Track if the goal is found

#     def get_percept(self, node):
#         return node

#     def mark_visited(self, node):
#         """Update environment to mark visited nodes."""
#         self.visited_nodes.append(node)
#         print(f"Environment updated: {node} marked as visited.")

#     def mark_goal_found(self, node):
#         """Update environment when goal is found."""
#         self.goal_found = True
#         print(f"Environment updated: Goal {node} reached!")

#     def show_environment_state(self):
#         """Display current environment status."""
#         print("\n=== Environment State ===")
#         print(f"Visited Nodes: {self.visited_nodes}")
#         print(f"Goal Found: {self.goal_found}")
#         print("=========================")


# def run_agent(agent, environment, start_node):
#     percept = environment.get_percept(start_node)
#     action = agent.act(percept, environment)  # Pass environment to agent
#     print(action)
#     environment.show_environment_state()  # Display updated environment


# # Tree Representation
# tree = {
#     'A': ['B', 'C'],
#     'B': ['D', 'E'],
#     'C': ['F', 'G'],
#     'D': ['H'],
#     'E': [],
#     'F': ['I'],
#     'G': [],
#     'H': [],
#     'I': []
# }

# # Define Start and Goal Nodes
# start_node = 'A'
# goal_node = 'I'

# # Create instances of agent and environment
# agent = GoalBasedAgent(goal_node)
# environment = Environment(tree)

# # Run the agent
# run_agent(agent, environment, start_node)
# Out:
# Visiting: A
# Environment updated: A marked as visited.
# Visiting: B
# Environment updated: B marked as visited.
# Visiting: C
# Environment updated: C marked as visited.
# Visiting: D
# Environment updated: D marked as visited.
# Visiting: E
# Environment updated: E marked as visited.
# Visiting: F
# Environment updated: F marked as visited.
# Visiting: G
# Environment updated: G marked as visited.
# Visiting: H
# Environment updated: H marked as visited.
# Visiting: I
# Environment updated: I marked as visited.
# Environment updated: Goal I reached!
# Goal I found!
#
# === Environment State ===
# Visited Nodes: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
# Goal Found: True
# =========================

# %% [markdown]
# #Eg# 2 BFS

# %% [markdown]
# ![CamScanner 01-29-2025 22.03_2.jpg](data:image/jpeg;base64,...)

# %%
# tree Representation
tree = {
    'A': ['B', 'C','D'],
    'B': ['E', 'F'],
    'C': ['G'],
    'D': ['H','I'],
    'E': ['J'],
    'F': ['K','L'],
    'G': [],
    'H': [],
    'I': ['M','N'],
    'J': [],
    'K': [],
    'L': [],
    'M': [],
    'N': [],

}

# BFS Function
def bfs(graph, start, goal):
    visited = []  # List for visited nodes
    queue = []    # Initialize a queue

    visited.append(start)
    queue.append(start)

    while queue:
        node = queue.pop(0)  # Dequeue
        print(node, end=" ")

        if node == goal:  # Stop if goal is found
            print("\nGoal found!")
            break

        for neighbour in graph[node]:
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)

# Define Start and Goal Nodes
start_node = 'A'
goal_node = 'M'

# Run BFS
print("\nFollowing is the Breadth-First Search (BFS):")
bfs(tree, start_node, goal_node)

# # Graph Representation
# graph = {
#     0: [1, 3],
#     1: [0, 3, 6],
#     2: [1],
#     3: [0, 1, 6, 4],
#     4: [3, 2, 5],
#     5: [4, 2, 6],
#     6: [3, 5, 4]
# }
# Out:
# Following is the Breadth-First Search (BFS):
# A B C D E F G H I J K L M
# Goal found!

# %% [markdown]
# #Eg 3

# %% [markdown]
# ![CamScanner 01-29-2025 22.03_3.jpg](data:image/jpeg;base64,...)

# %%
# Graph Representation
graph = {
    0: [1, 3],
    1: [0, 3],
    2: [4,5],
    3: [0, 1, 6, 4],
    4: [3, 2, 5],
    5: [4, 2, 6],
    6: [3, 5]
}


# BFS Function
def bfs(graph, start, goal):
    visited = []  # List for visited nodes
    queue = []    # Initialize a queue

    visited.append(start)
    queue.append(start)

    while queue:
        node = queue.pop(0)  # Dequeue
        print(node, end=" ")

        if node == goal:  # Stop if goal is found
            print("\nGoal found!")
            break

        for neighbour in graph[node]:
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)

# Define Start and Goal Nodes
start_node =0
goal_node = 5

# Run BFS
print("\nFollowing is the Breadth-First Search (BFS):")
bfs(graph, start_node, goal_node)
# Out:
# Following is the Breadth-First Search (BFS):
# 0 1 3 6 4 5
# Goal found!

# %% [markdown]
# #Eg 4 BFS

# %% [markdown]
# ![CamScanner 01-29-2025 22.03_4.jpg](data:image/jpeg;base64,...)

# %%
maze = [
    [1, 1, 0,1],
    [1, 1, 1,0],
    [0, 1, 1.,0]
]
len(maze[0])
# Out:
# 4

# %%
# Maze representation as a graph
maze = [
    [1, 1, 0],
    [1, 1, 1],
    [0, 1, 1]
]

# Directions for movement (right and down)
directions = [(0, 1), (1, 0)]  # (row, col)

# Convert maze to a graph (adjacency list representation)
def create_graph(maze):
    graph = {}
    rows = len(maze)
    cols = len(maze[0])

    for i in range(rows):
        for j in range(cols):
            if maze[i][j] == 1:  # If it's an open path
                neighbors = []
                for dx, dy in directions:  #[(0,1) .. dx ] , [(1,0)].... dy
                    nx, ny = i + dx, j + dy
                    if 0 <= nx < rows and 0 <= ny < cols and maze[nx][ny] == 1:
                        neighbors.append((nx, ny))
                graph[(i, j)] = neighbors
    return graph

# BFS Function using queue
def bfs(graph, start, goal):
    visited = []  # List for visited nodes
    queue = []    # Initialize queue

    visited.append(start)
    queue.append(start)

    while queue:
        node = queue.pop(0)  # FIFO: Dequeue from front
        print(node, end=" ")

        if node == goal:  # Stop if goal is found
            print("\nGoal found!")
            break

        for neighbour in graph[node]:  # Visit neighbors
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)

# Create graph from maze
graph = create_graph(maze)

# Define Start and Goal nodes
start_node = (0, 0)  # Starting point (0,0)
goal_node = (2, 2)   # Goal point (2,2)

# Run BFS
print("\nFollowing is the Breadth-First Search (BFS):")
bfs(graph, start_node, goal_node)
# Out:
# Following is the Breadth-First Search (BFS):
# (0, 0) (0, 1) (1, 0) (1, 1) (1, 2) (2, 1) (2, 2)
# Goal found!

# %% [markdown]
# #**DFS (Depth First Search)**

# %%
# tree Representation
tree = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F', 'G'],
    'D': ['H'],
    'E': [],
    'F': ['I'],
    'G': [],
    'H': [],
    'I': []
}


# DFS Function
def dfs(graph, start, goal):
    visited = []  # List for visited nodes
    stack = []    # Initialize stack

    visited.append(start)
    stack.append(start)

    while stack:
        node = stack.pop(-1)  # LIFO: Pop from top
        print(node, end=" ")

        if node == goal:  # Stop if goal is found
            print("\nGoal found!")
            break

        for neighbour in reversed(graph[node]):  # Reverse to maintain correct order
            if neighbour not in visited:
                visited.append(neighbour)
                stack.append(neighbour)

# Define Start and Goal Nodes
start_node = 'A'
goal_node = 'I'

# Run DFS
print("\nFollowing is the Depth-First Search (DFS):")
dfs(graph, start_node, goal_node)
# Out:
# Following is the Depth-First Search (DFS):
# A B D H E C F I
# Goal found!

# %% [markdown]
# #Converting Eg#1 of DFS in Goal Based Agent

# %%
class GoalBasedAgent:
    def __init__(self, goal):
        self.goal = goal

    def formulate_goal(self, percept):
        if percept == self.goal:
            return "Goal reached"
        return "Searching"

    def dfs_search(self, graph, start, goal):
        visited = []  # List for visited nodes
        stack = []    # Initialize stack

        visited.append(start)
        stack.append(start)

        while stack:
            node = stack.pop()  # LIFO: Pop from top
            print(f"Visiting: {node}")

            if node == goal:  # Stop if goal is found
                return f"Goal {goal} found!"

            for neighbour in reversed(graph.get(node, [])):
                if neighbour not in visited:
                    visited.append(neighbour)
                    stack.append(neighbour)

        return "Goal not found"

    def act(self, percept, graph):
        goal_status = self.formulate_goal(percept)
        if goal_status == "Goal reached":
            return f"Goal {self.goal} found!"
        else:
            return self.dfs_search(graph, percept, self.goal)


class Environment:
    def __init__(self, graph):
        self.graph = graph

    def get_percept(self, node):
        return node


def run_agent(agent, environment, start_node):
    percept = environment.get_percept(start_node)
    action = agent.act(percept, environment.graph)  # Pass graph to agent
    print(action)


# Tree Representation
tree = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F', 'G'],
    'D': ['H'],
    'E': [],
    'F': ['I'],
    'G': [],
    'H': [],
    'I': []
}

# Define Start and Goal Nodes
start_node = 'A'
goal_node = 'I'

# Create instances of agent and environment
agent = GoalBasedAgent(goal_node)
environment = Environment(tree)

# Run the agent
run_agent(agent, environment, start_node)
# Out:
# Visiting: A
# Visiting: B
# Visiting: D
# Visiting: H
# Visiting: E
# Visiting: C
# Visiting: F
# Visiting: I
# Goal I found!

# %% [markdown]
# #Eg2 DFS

# %%
# tree Representation
tree = {
    'A': ['B', 'C','D'],
    'B': ['E', 'F'],
    'C': ['G'],
    'D': ['H','I'],
    'E': ['J'],
    'F': ['K','L'],
    'G': [],
    'H': [],
    'I': ['M','N'],
    'J': [],
    'K': [],
    'L': [],
    'M': [],
    'N': [],

}


# DFS Function
def dfs(graph, start, goal):
    visited = []  # List for visited nodes
    stack = []    # Initialize stack

    visited.append(start)
    stack.append(start)

    while stack:
        node = stack.pop()  # LIFO: Pop from top
        print(node, end=" ")

        if node == goal:  # Stop if goal is found
            print("\nGoal found!")
            break

        for neighbour in reversed(graph[node]):  # Reverse to maintain correct order
            if neighbour not in visited:
                visited.append(neighbour)
                stack.append(neighbour)

# Define Start and Goal Nodes
start_node = 'A'
goal_node = 'M'

# Run DFS
print("\nFollowing is the Depth-First Search (DFS):")
dfs(graph, start_node, goal_node)
# Out:
# Following is the Depth-First Search (DFS):
# A B E J F K L C G D H I M
# Goal found!

# %% [markdown]
# #Eg 3 DFS

# %%
# Graph Representation
graph = {
    0: [1, 3],
    1: [0, 3],
    2: [4,5],
    3: [0, 1, 6, 4],
    4: [3, 2, 5],
    5: [4, 2, 6],
    6: [3, 5]
}


# DFS Function
def dfs(graph, start, goal):
    visited = []  # List for visited nodes
    stack = []    # Initialize stack

    visited.append(start)
    stack.append(start)

    while stack:
        node = stack.pop()  # LIFO: Pop from top
        print(node, end=" ")

        if node == goal:  # Stop if goal is found
            print("\nGoal found!")
            break

        for neighbour in reversed(graph[node]):  # Reverse to maintain correct order
            if neighbour not in visited:
                visited.append(neighbour)
                stack.append(neighbour)

# Define Start and Goal Nodes
start_node = 0
goal_node = 5

# Run DFS
print("\nFollowing is the Depth-First Search (DFS):")
dfs(graph, start_node, goal_node)
# Out:
# Following is the Depth-First Search (DFS):
# 0 1 3 6 5
# Goal found!

# %%
# Maze representation as a graph
maze = [
    [1, 1, 0],
    [0, 1, 0],
    [0, 1, 1]
]

# Directions for movement (right and down)
directions = [(0, 1), (1, 0)]  # (row, col)

# Convert maze to a graph (adjacency list representation)
def create_graph(maze):
    graph = {}
    rows = len(maze)
    cols = len(maze[0])

    for i in range(rows):
        for j in range(cols):
            if maze[i][j] == 1:  # If it's an open path
                neighbors = []
                for dx, dy in directions:
                    nx, ny = i + dx, j + dy
                    if 0 <= nx < rows and 0 <= ny < cols and maze[nx][ny] == 1:
                        neighbors.append((nx, ny))
                graph[(i, j)] = neighbors
    return graph

# DFS Function using stack
def dfs(graph, start, goal):
    visited = []  # List for visited nodes
    stack = []    # Initialize stack

    visited.append(start)
    stack.append(start)

    while stack:
        node = stack.pop()  # LIFO: Pop from top
        print(node, end=" ")

        if node == goal:  # Stop if goal is found
            print("\nGoal found!")
            break

        for neighbour in graph[node]:  # Visit neighbors
            if neighbour not in visited:
                visited.append(neighbour)
                stack.append(neighbour)

# Create graph from maze
graph = create_graph(maze)

# Define Start and Goal nodes
start_node = (0, 0)  # Starting point (0,0)
goal_node = (2, 2)   # Goal point (2,2)

# Run DFS
print("\nFollowing is the Depth-First Search (DFS):")
dfs(graph, start_node, goal_node)
# Out:
# Following is the Depth-First Search (DFS):
# (0, 0) (0, 1) (1, 1) (2, 1) (2, 2)
# Goal found!

# %% [markdown]
# #Depth Limited Search

# %%
# Graph without weights for DLS
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F', 'G'],
    'D': ['H'],
    'E': [],
    'F': ['I'],
    'G': [],
    'H': [],
    'I': []
}

# DLS Function
def dls(graph, start, goal, depth_limit):
    visited = []
    def dfs(node, depth):
        if depth > depth_limit:
            return None  # Limit reached
        visited.append(node)
        if node == goal:
            print(f"Goal found with DLS. Path: {visited}")
            # return visited
        for neighbor in graph.get(node, []):
            if neighbor not in visited:
                path = dfs(neighbor, depth + 1)
                if path:
                    return path
        visited.pop()  # Backtrack if goal not found
        return None

    return dfs(start, 0)

# Run DLS with depth limit 3
dls(graph, 'A', 'I', 3)
# Out:
# Goal found with DLS. Path: ['A', 'C', 'F', 'I']

# %%
#IDS
# Graph representation (Adjacency List)
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F', 'G'],
    'D': ['H'],
    'E': [],
    'F': ['I'],
    'G': [],
    'H': [],
    'I': []
}

# Depth Limited Search (DLS)
def dls(graph, node, goal, depth_limit, visited):
    if depth_limit < 0:
        return None

    visited.append(node)

    if node == goal:
        return visited.copy()

    for neighbor in graph.get(node, []):
        if neighbor not in visited:
            path = dls(graph, neighbor, goal, depth_limit - 1, visited)
            if path:
                return path

    visited.pop()   # Backtracking
    return None


# Iterative Deepening Search (IDS)
def ids(graph, start, goal, max_depth):
    for depth in range(max_depth + 1):
        print(f"\nDepth Limit = {depth}")
        visited = []
        path = dls(graph, start, goal, depth, visited)

        if path:
            print("Goal Found!")
            print("Path:", path)
            return path

    print("Goal not found within depth limit")
    return None


# -------- Main --------
start_node = 'A'
goal_node = 'I'
max_depth = 4

print("Iterative Deepening Search:")
ids(graph, start_node, goal_node, max_depth)
# Out:
# Iterative Deepening Search:
#
# Depth Limit = 0
#
# Depth Limit = 1
#
# Depth Limit = 2
#
# Depth Limit = 3
# Goal Found!
# Path: ['A', 'C', 'F', 'I']
# ['A', 'C', 'F', 'I']

# %% [markdown]
# #UCS

# %%
# Graph with different edge costs for UCS
graph = {
    'A':{'B': 2, 'C': 1} ,
    'B': {'D': 4, 'E': 3},
    'C': {'F': 1, 'G': 5},
    'D': {'H': 2},
    'E': {},
    'F': {'I': 6},
    'G': {},
    'H': {},
    'I': {}
}
#f(n)=g(n)
# UCS Function with Frontier and Visited
def ucs(graph, start, goal):
    # Initialize the frontier with the start node and cost 0
    frontier = [(start, 0)]  # (node, cost)
    visited = set()  # Set to keep track of visited nodes
    cost_so_far = {start: 0}  # Cost to reach each node
    came_from = {start: None}  # Path reconstruction

    while frontier:
        # Sort frontier by cost, simulate priority queue
        frontier.sort(key=lambda x: x[1])

        # Pop the node with the lowest cost
        current_node, current_cost = frontier.pop(0)

        # If we've already visited this node, skip it
        if current_node in visited:
            continue

        # Mark the current node as visited
        visited.add(current_node)

        # If we reach the goal, reconstruct the path and return
        if current_node == goal:
            path = []
            while current_node is not None:
                path.append(current_node)
                current_node = came_from[current_node]
            path.reverse()
            print(f"Goal found with UCS. Path: {path}, Total Cost: {current_cost}")
            return

        # Explore neighbors
        for neighbor, cost in graph[current_node].items():
            new_cost = current_cost + cost
            if neighbor not in cost_so_far or new_cost < cost_so_far[neighbor]:
                cost_so_far[neighbor] = new_cost
                came_from[neighbor] = current_node
                frontier.append((neighbor, new_cost))  # Add to frontier

    print("Goal not found")

# Run UCS with updated costs, using frontier and visited
ucs(graph, 'A', 'I')
# Out:
# Goal found with UCS. Path: ['A', 'C', 'F', 'I'], Total Cost: 8

# %%
import heapq

class GoalBasedAgent:
    def __init__(self, goal):
        self.goal = goal

    def formulate_goal(self, percept):
        if percept == self.goal:
            return "Goal reached"
        return "Searching"

    def act(self, percept, environment):
        goal_status = self.formulate_goal(percept)
        if goal_status == "Goal reached":
            return f"Goal {self.goal} found!"
        else:
            return environment.ucs_search(percept, self.goal)


class Environment:
    def __init__(self, graph):
        self.graph = graph

    def get_percept(self, node):
        return node

    def ucs_search(self, start, goal):
        frontier = [(0, start)]  # Priority queue (cost, node)
        visited = set()
        cost_so_far = {start: 0}
        came_from = {start: None}

        while frontier:
            current_cost, current_node = heapq.heappop(frontier)

            if current_node in visited:
                continue

            visited.add(current_node)

            if current_node == goal:
                path = []
                while current_node is not None:
                    path.append(current_node)
                    current_node = came_from[current_node]
                path.reverse()
                return f"Goal {goal} found with UCS. Path: {path}, Total Cost: {current_cost}"

            for neighbor, cost in self.graph.get(current_node, {}).items():
                new_cost = current_cost + cost
                if neighbor not in cost_so_far or new_cost < cost_so_far[neighbor]:
                    cost_so_far[neighbor] = new_cost
                    came_from[neighbor] = current_node
                    heapq.heappush(frontier, (new_cost, neighbor))

        return "Goal not found"


def run_agent(agent, environment, start_node):
    percept = environment.get_percept(start_node)
    action = agent.act(percept, environment)
    print(action)


# Graph Representation with Costs
graph = {
    'A': {'B': 2, 'C': 1},
    'B': {'D': 4, 'E': 3},
    'C': {'F': 1, 'G': 5},
    'D': {'H': 2},
    'E': {},
    'F': {'I': 6},
    'G': {},
    'H': {},
    'I': {}
}

# Define Start and Goal Nodes
start_node = 'A'
goal_node = 'I'

# Create instances of agent and environment
agent = GoalBasedAgent(goal_node)
environment = Environment(graph)

# Run the agent
run_agent(agent, environment, start_node)
# Out:
# Goal I found with UCS. Path: ['A', 'C', 'F', 'I'], Total Cost: 8
